# %% [markdown]
# __Name : Tahir fareed__
#
# __Roll No: SU92-BBSAIM_F24-036__
#
# __Program: Artificial intelligence (1-A)__

# %%
import pandas as pd

# %%
data=pd.read_csv("Salary_Data.csv")
data
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
data.head(5)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.tail(10)
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 6694  27.0    Male        High School         Digital Marketing Manager
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6696  28.0    Male                PhD              Sales Representative
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6698  37.0    Male  Bachelor's Degree       Junior Sales Representative
# 6699  49.0  Female                PhD             Director of Marketing
# 6700  32.0    Male        High School                   Sales Associate
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager
# 6702  46.0    Male    Master's Degree                 Marketing Manager
# 6703  26.0  Female        High School                   Sales Executive
#
#       Years of Experience    Salary
# 6694                  2.0   40000.0
# 6695                  7.0   90000.0
# 6696                  4.0   55000.0
# 6697                 19.0  190000.0
# 6698                  6.0   75000.0
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
data.sample(7)
# Out:
#        Age  Gender    Education Level                       Job Title  \
# 1266  57.0    Male                PhD       Software Engineer Manager
# 4674  26.0  Female  Bachelor's Degree        Junior Software Engineer
# 3578  43.0  Female                PhD  Senior Human Resources Manager
# 6318  35.0    Male                PhD               Marketing Manager
# 1721  46.0    Male                PhD         Senior Project Engineer
# 2044  33.0  Female  Bachelor's Degree             Full Stack Engineer
# 1766  41.0    Male                PhD         Senior Project Engineer
#
#       Years of Experience    Salary
# 1266                 16.0  195000.0
# 4674                  1.0   45000.0
# 3578                 15.0  150000.0
# 6318                  8.0   80000.0
# 1721                 14.0  180000.0
# 2044                  6.0  115000.0
# 1766                 13.0  185000.0

# %%
data.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
data.describe(include="all")
# Out:
#                 Age Gender    Education Level          Job Title  \
# count   6702.000000   6702               6701               6702
# unique          NaN      3                  7                193
# top             NaN   Male  Bachelor's Degree  Software Engineer
# freq            NaN   3674               2267                518
# mean      33.620859    NaN                NaN                NaN
# std        7.614633    NaN                NaN                NaN
# min       21.000000    NaN                NaN                NaN
# 25%       28.000000    NaN                NaN                NaN
# 50%       32.000000    NaN                NaN                NaN
# 75%       38.000000    NaN                NaN                NaN
# max       62.000000    NaN                NaN                NaN
#
#         Years of Experience         Salary
# count           6701.000000    6699.000000
# unique                  NaN            NaN
# top                     NaN            NaN
# freq                    NaN            NaN
# mean               8.094687  115326.964771
# std                6.059003   52786.183911
# min                0.000000     350.000000
# 25%                3.000000   70000.000000
# 50%                7.000000  115000.000000
# 75%               12.000000  160000.000000
# max               34.000000  250000.000000

# %%
data["Education Level"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Education Level'>

# %%
data["Education Level"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Education Level'>

# %%
data["Education Level"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Education Level'>

# %%
data["Education Level"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Education Level"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Education Level"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
data["Education Level"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Education Level'>

# %%
(data.isnull().sum())
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
data.fillna(12,inplace=True)
data
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
data.dropna()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
data.drop_duplicates()
# Out:
#        Age  Gender    Education Level                  Job Title  \
# 0     32.0    Male         Bachelor's          Software Engineer
# 1     28.0  Female           Master's               Data Analyst
# 2     45.0    Male                PhD             Senior Manager
# 3     36.0  Female         Bachelor's            Sales Associate
# 4     52.0    Male           Master's                   Director
# ...    ...     ...                ...                        ...
# 6623  43.0  Female    Master's Degree  Digital Marketing Manager
# 6624  27.0    Male        High School              Sales Manager
# 6625  33.0  Female  Bachelor's Degree      Director of Marketing
# 6628  37.0    Male  Bachelor's Degree             Sales Director
# 6631  30.0  Female  Bachelor's Degree              Sales Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6623                 15.0  150000.0
# 6624                  2.0   40000.0
# 6625                  8.0   80000.0
# 6628                  7.0   90000.0
# 6631                  5.0   70000.0
#
# [1792 rows x 6 columns]

# %%
data.duplicated
# Out:
# <bound method DataFrame.duplicated of        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]>

# %%
data.loc[6703]
# Out:
# Age                               26.0
# Gender                          Female
# Education Level            High School
# Job Title              Sales Executive
# Years of Experience                1.0
# Salary                         35000.0
# Name: 6703, dtype: object

# %%
data["Job Title"]
# Out:
# 0           Software Engineer
# 1                Data Analyst
# 2              Senior Manager
# 3             Sales Associate
# 4                    Director
#                 ...
# 6699    Director of Marketing
# 6700          Sales Associate
# 6701        Financial Manager
# 6702        Marketing Manager
# 6703          Sales Executive
# Name: Job Title, Length: 6704, dtype: object

# %%
data["Years of Experience"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6704 entries, 0 to 6703
# Series name: Years of Experience
# Non-Null Count  Dtype
# --------------  -----
# 6704 non-null   float64
# dtypes: float64(1)
# memory usage: 52.5 KB

# %%
data["Salary"].sum()
# Out:
# np.float64(772575397.0)
